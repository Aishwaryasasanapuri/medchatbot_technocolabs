# 21332  https://www.drugs.com/cons/zyvox-intravenous.html
# 21333  https://www.drugs.com/cdi/zyvox-linezolid-inje...
# 21334  https://www.drugs.com/cdi/zyvox-linezolid-susp...
# 21335  https://www.drugs.com/cdi/zyvox-linezolid-tabl...
#
#                                                     Name
# 0                                               Abacavir
# 1                 Abacavir, dolutegravir, and lamivudine
# 2                                Abacavir and lamivudine
# 3                        Abacavir and Lamivudine Tablets
# 4                   Abacavir, lamivudine, and zidovudine
# 5            Abacavir, Lamivudine and Zidovudine Tablets
# 6                                 Abacavir Oral Solution
# 7                               Abacavir Sulfate Tablets
# 8                                       Abacavir Tablets
# 9                                          Abaloparatide
# 10                            Abaloparatide Subcutaneous
# 11                                            Abametapir
# 12                                             Abatacept
# 13                              Abatacept Auto-Injectors
# 14                                    Abatacept Infusion
# 15                                 Abatacept Intravenous
# 16                          Abatacept Prefilled Syringes
# 17                                               Abatron
# 18                                           Abatuss DMX
# 19                                            Abbokinase
# 20                                             Abciximab
# 21                                 Abciximab Intravenous
# 22                                                 ABDEK
# 23                                               Abelcet
# 24                                           Abemaciclib
# 25                                                Abenol
# 26                                               Abilify
# 27                      Abilify (Aripiprazole Injection)
# 28                  Abilify (Aripiprazole Oral Solution)
# 29                        Abilify (Aripiprazole Tablets)
# ...                                                  ...
# 21306                                       Zypram Cream
# 21307                                            Zyprexa
# 21308                                  ZyPREXA injection
# 21309                              Zyprexa Intramuscular
# 21310                                   Zyprexa Relprevv
# 21311                                      Zyprexa Zydis
# 21312                                            Zyrexal
# 21313                                             Zyrtec
# 21314                                     Zyrtec Capsule
# 21315           Zyrtec (Cetirizine Capsules and Tablets)
# 21316               Zyrtec (Cetirizine Chewable Tablets)
# 21317                         Zyrtec (Cetirizine Liquid)
# 21318  Zyrtec (Cetirizine Orally Disintegrating Tablets)
# 21319                                           Zyrtec-D
# 21320                                   Zyrtec-D 12 Hour
# 21321                      ZyrTEC-D Allergy & Congestion
# 21322                                      Zyrtec-D Oral
# 21323                                   Zyrtec Itchy Eye
# 21324                                       Zyrtec Syrup
# 21325                                     Zyrtec Tablets
# 21326                                             Zytiga
# 21327                                        Zytiga Oral
# 21328                                            Zytopic
# 21329                                            Zyvodol
# 21330                                              Zyvox
# 21331                                    Zyvox Injection
# 21332                                  Zyvox Intravenous
# 21333                        Zyvox (Linezolid Injection)
# 21334                       Zyvox (Linezolid Suspension)
# 21335                          Zyvox (Linezolid Tablets)
#
# [21336 rows x 2 columns]

# %%
med2 = pd.DataFrame(columns=['Caution'])
for url in medicine.Link:   
    rs = requests.get(url)
    sp = BeautifulSoup(rs.text,'html.parser')
    target = sp.find('h2',text='Important Information')
    try:
        for sib in target.find_next_siblings():
            if sib.name=='h2':
                break
            else:
                med2 = med2.append({'Caution':sib.text},ignore_index=True)
                break
    except:
        med2 = med2.append({'Caution':'None'},ignore_index=True)

# %%
med2.to_csv('Caution.csv')
# Out:
#                                                  Des
# 0  You should not take this medicine if you have ...
# 1  You should not take this medicine if you have ...
# 2  You should not take  abacavir and lamivudine i...
# 3                                               None
# 4  Stop taking this medicine and call your doctor...
# 5                                               None

# %% [markdown]
# ## TRY TO RUN THIS CODE. IT WILL FETCH THE INFORMATION ABOUT EACH MEDICINE. IT MAY TAKE FEW HOURS TO COMPLETE  BECAUSE THE AMOUNT OF DATA IS HUGE
